# %%
from yolo_deepsort import main
track = main()
track()
# Out:
# after load model
# 0: 480x640 1 traffic light, 4.5ms
# Speed: 4.1ms preprocess, 4.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 traffic light, 2.2ms
# Speed: 4.8ms preprocess, 2.2ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 3.0ms
# Speed: 3.6ms preprocess, 3.0ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 traffic light, 2.1ms
# Speed: 4.4ms preprocess, 2.1ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 traffic light, 2.5ms
# Speed: 3.3ms preprocess, 2.5ms inference, 7.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 traffic light, 2.8ms
# Speed: 4.1ms preprocess, 2.8ms inference, 5.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 traffic light, 2.9ms
# Speed: 4.6ms preprocess, 2.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# ...
