# %%
from yolo_deepsort import main
track = main()
track()
# Out:
# after load model
# 0: 480x640 2 cars, 1 truck, 37.4ms
# Speed: 6.3ms preprocess, 37.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 bus, 1 truck, 3.9ms
# Speed: 4.3ms preprocess, 3.9ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 2.1ms
# Speed: 3.6ms preprocess, 2.1ms inference, 8.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 bus, 4.8ms
# Speed: 7.5ms preprocess, 4.8ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 2.7ms
# Speed: 3.5ms preprocess, 2.7ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 truck, 5.5ms
# Speed: 7.0ms preprocess, 5.5ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 truck, 2.6ms
# Speed: 4.3ms preprocess, 2.6ms inference, 5.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 truck, 2.8ms
# ...
